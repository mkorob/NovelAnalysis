# %% [markdown]
# <a href="https://colab.research.google.com/github/mkorob/NovelAnalysis/blob/main/Another_copy_of_Yet_another_copy_of_GoneWithTheWind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gone With The Wind Character Analysis

# %% [markdown]
# Summary of what this notebook does to insert later.

# %% [markdown]
# ## 0. Preliminaries

# %%
import requests
import pandas as pd
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize
import re
from bs4 import BeautifulSoup

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('punkt')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## 1. Load Gone With The Wind Text from Gutenberg

# %%
# URL of "Gone with the Wind" on Project Gutenberg
url = "https://gutenberg.net.au/ebooks02/0200161.txt"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Extract the content of the book
    content = response.text

    # Remove Project Gutenberg's header and footer
    start_index = content.find("CHAPTER I")
    end_index = content.find("THE END")
    content = content[start_index:end_index]

    # Display the first 500 characters of the content
    print(content[:500])
else:
    print("Failed to retrieve the book from Project Gutenberg.")
# Out:
# CHAPTER I
#
#
# Scarlett O'Hara was not beautiful, but men seldom realized it when
# caught by her charm as the Tarleton twins were.  In her face were
# too sharply blended the delicate features of her mother, a Coast
# aristocrat of French descent, and the heavy ones of her florid
# Irish father.  But it was an arresting face, pointed of chin,
# square of jaw.  Her eyes were pale green without a touch of hazel,
# starred with bristly black lashes and slightly tilted at the ends.
# Above them, her thick black bro

# %%
#check the start and the end of the novel
print(f"The Start of the GTTW : {content[:100]}")
print(f"The End of the GTTW : {content[-100:]}")
# Out:
# The Start of the GTTW : CHAPTER I
#
#
# Scarlett O'Hara was not beautiful, but men seldom realized it when
# caught by her charm a
# The End of the GTTW : it then.
# Tomorrow, I'll think of some way to get him back.  After all,
# tomorrow is another day."

# %% [markdown]
# ## 2. Extract Main Characters

# %% [markdown]
# To analyze interactions, we need to map the named entities in the text to the names of the main characters. Here, we make a list of all characters in the novel the way they are referred to in a novel and map them to a unique list of characters in the novel. (e.g. "Catherine", "Cathy", -> "Catherine").

# %%
import spacy

# %%
def extract_characters(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    named_entities = set()
    for ent in doc.ents:
        if ent.label_ in ["PERSON"]:
            named_entities.add(ent.text)

    return sorted(named_entities)

# %%
len(content)
# Out:
# 2340566

# %%
#Spacy NER's extractor needs shorter texts so we split in thirds
thir_content = int(len(content)/3)
characters1 = extract_characters(content[:thir_content])
characters2 = extract_characters(content[thir_content:(thir_content*2)])
characters3 = extract_characters(content[(thir_content*2):])

# %%
characters = set(characters1) | set(characters2) | set(characters3)

# %%
characters = [c for c in list(characters) if c[0].isupper()]

# %%
len(characters)
# Out:
# 778

# %%
characters = sorted(characters)

# %%
#remove any characters that are subsets of one another (e.g. no need for Charles and Charles Hamilton)
unique_characters = set()
for name in characters:
    if not any(f"{n.strip()} " in name.strip() or f"{n.strip()}\n" in name.strip() for n in unique_characters):
        unique_characters.add(name)

# %%
len(unique_characters)
# Out:
# 535

# %%
#export the dataframe to CSV and manually match characters
pd.DataFrame(characters).to_csv("possible_characters.csv")

# %%
#export the dataframe to CSV and manually match characters
pd.DataFrame(unique_characters).to_csv("possible_reduced_characters_v2.csv")

# %%
#import the completed list
characters = pd.read_excel("/content/possible_reduced_characters_v2 (1).xlsx")

# %%
#this is old output, the new one should have two columns, one for name as in book, the second for the "real name"
characters = characters[['character', 'character_real']].loc[characters['character_real'] != "remove", :].reset_index(drop = True)

# %%
characters
# Out:
#        character character_real
# 0           Rosa           Rosa
# 1        Watling        Watling
# 2    Kill Ashley         Ashley
# 3          Darcy          Darcy
# 4         Ulster         Ulster
# ..           ...            ...
# 221  Sadie Belle          Belle
# 222       Wynder         Wynder
# 223         Rene           Rene
# 224         Pork           Pork
# 225        India          India
#
# [226 rows x 2 columns]

# %%
characters['character_real'].unique()
# Out:
# array(['Rosa', 'Watling', 'Ashley', 'Darcy', 'Ulster', 'Scarlett',
#        'Bonnie', 'Jeff\nDavis', 'Mammy', 'Merriwether', 'Jack', 'Munroe',
#        'Fontaine', 'Pauline', 'Dan Tucker', 'Buck Munroe', 'Rhett',
#        'Mick', 'Pharisees', 'Poke', 'Pitty', 'Sam', 'Suellen', 'Bullock',
#        'Prissy', 'Susan Elinor', 'Sarah Jane', 'Phillip', 'Melanie',
#        'Nathan Bedford Forrest', 'Frank', 'Robillard', 'Will', 'Bub',
#        'McRae', 'Johnson', 'Tarleton', 'Henry', 'Burdens', 'Paul Wilson',
#        'Doc Fontaine', 'Charles', 'Andy Bonnell', 'Betsy', 'Carreen',
#        'Brown', 'Morgan', 'Wade', 'Calverts', 'Emmie', 'Jonas', 'Betty',
#        'Archie', 'Cathleen', 'Jane', 'Jerry', 'Dilcey', 'Brenton',
#        'Hilton', 'Tom', 'Alex', 'Jim', 'Sylvia', 'Beau', 'Hetty Tarleton',
#        'Suzannah Talbot', 'Elsing', 'Lou', 'Boyne', 'Calhoun',
#        'Dolly Merriwether', 'Meade', 'John', 'Stuart', 'Caroline Irene',
#        'Jeb Stuart', 'Gerald', 'Hugh', 'Melissy', 'Bonnell', 'Wilkerson',
#        'Talbot', 'Beatrice', 'Maybelle', 'Peter', 'Johnston', 'Uncle',
#        'Boyd', 'James', 'Andrew', 'Ella Lorena', 'Sloan', 'Brent',
#        'Allan', 'Tomlinson', 'Rebecca', 'Mary', 'Davis', 'Aunt',
#        'Hamiltons', 'Letty\nMunroe', 'Allison', 'Prudhomme', 'Hampton',
#        'Nellie', 'Careen', 'Mose', 'Toby', 'Wilkens', 'Frankie Bonnell',
#        'Tony', 'Belle', 'Bob Toombs', "Angus MacIntosh's", 'Joe',
#        'Merriweather', 'Levi', 'Ellen', 'Medusa', 'Dean', 'Eulalie',
#        'Philippe', 'Dallas McLure', 'Nathan\nBedford Forrest', 'Johnnie',
#        'Pittypat', 'Sally', 'Bill', 'Adam', 'Ryan', 'Gallic', 'Wynder',
#        'MacIntosh', 'Dimity Munroe', 'Kitty Bonnell', 'Alice Munroe',
#        'Jones', 'Gordon', 'Raiford Calvert', 'Rene', 'Pork', 'India'],
#       dtype=object)

# %% [markdown]
# ## 3. Split Text into Narrative and Dialogue

# %%
def split_text(text):

    sections = []

    inside_quote = False
    start_index = 0
    end_index = 0
    current_quote_type = "Narrative"
    count_quotations =0

    for i, char in enumerate(text):
        if char == '"' and count_quotations == 0:
            if not inside_quote and text[i+1].isupper():
                #append existing text
                sections.append({ 'text': text[start_index:i].strip(), 'type': "Narrative"})
                #start end
                inside_quote = True
                start_index = i
                current_quote_type = 'Dialogue'
                count_quotations = 1
        elif char == '"' and count_quotations == 1:
            if inside_quote:
                inside_quote = False
                end_index = i
                #append existing text
                sections.append({ 'text': text[start_index:end_index+1].strip(), 'type': "Dialogue"})
                start_index = i +1
                count_quotations = 0
    return sections

# %%
#split text into sections
def split_text_into_sections(text):
    sections = []

    for line in text.split('\r\n\r\n'):
        line = line.strip()
        if line:
          if '"' in line:
            sections = sections + split_text(line)
          else:
            sections.append({'text': line, 'type': 'Narrative'})

    df = pd.DataFrame(sections)
    return df

# %%
result_df = split_text_into_sections(content)
#filter out empty sections (paragraphs spaces)
result_df = result_df.loc[result_df['text'] != "", ]

# %%
result_df
# Out:
#                                                     text       type
# 0      CHAPTER I\n\n\nScarlett O'Hara was not beautif...  Narrative
# 1      "I know you two don't care about being expelle...   Dialogue
# 2                                              she said.  Narrative
# 3      "But what about Boyd?  He's kind of set on get...   Dialogue
# 5      "Oh, he can read law in Judge Parmalee's offic...   Dialogue
# ...                                                  ...        ...
# 13005                         "I won't think of it now,"   Dialogue
# 13006  she said again, aloud, trying to push\nher mis...  Narrative
# 13007       "I'll--why, I'll go home to Tara\ntomorrow,"   Dialogue
# 13008  and her spirits lifted faintly.\n\nShe had gon...  Narrative
# 13009  "I'll think of it all tomorrow, at Tara.  I ca...   Dialogue
#
# [10450 rows x 2 columns]

# %%
#export df to check for any issues
result_df.to_csv("content_df.csv")

# %%
result_df.head(n = 50)
# Out:
#                                                  text       type
# 0   CHAPTER I\n\n\nScarlett O'Hara was not beautif...  Narrative
# 1   "I know you two don't care about being expelle...   Dialogue
# 2                                           she said.  Narrative
# 3   "But what about Boyd?  He's kind of set on get...   Dialogue
# 5   "Oh, he can read law in Judge Parmalee's offic...   Dialogue
# 6                          answered Brent carelessly.  Narrative
# 7   "Besides, it don't\nmatter much.  We'd have ha...   Dialogue
# 9                                              "Why?"   Dialogue
# 11  "The war, goose!  The war's going to start any...   Dialogue
# 13        "You know there isn't going to be any war,"   Dialogue
# 14                              said Scarlett, bored.  Narrative
# 15  "It's all just talk.  Why, Ashley Wilkes and h...   Dialogue
# 17                         "Not going to be any war!"   Dialogue
# 18  cried the twins indignantly, as though\nthey h...  Narrative
# 19  "Why, honey, of course there's going to be a w...   Dialogue
# 20                                       said Stuart.  Narrative
# 21  "The Yankees may be scared of us, but after th...   Dialogue
# 22         Scarlett made a mouth of bored impatience.  Narrative
# 23  "If you say 'war' just once more, I'll go in t...   Dialogue
# 24  She meant what she said, for she could never l...  Narrative
# 25  "What did your mother say about you two being ...   Dialogue
# 26  The boys looked uncomfortable, recalling their...  Narrative
# 27                                            "Well,"   Dialogue
# 28  said Stuart, "she hasn't had a chance to say a...  Narrative
# 29  "Didn't she say anything when you got home las...   Dialogue
# 31  "We were in luck last night.  Just before we g...   Dialogue
# 33                  "Do you suppose she'll hit Boyd?"   Dialogue
# 34  Scarlett, like the rest of the\nCounty, could ...  Narrative
# 35  "Of course she won't hit Boyd.  She never did ...   Dialogue
# 36            said Stuart, proud of his six feet two.  Narrative
# 37  "That's why we left him\nat home to explain th...   Dialogue
# 39  "Will your mother ride the new horse to the Wi...   Dialogue
# 41  "She wants to, but Pa says he's too dangerous....   Dialogue
# 43                 "I hope it doesn't rain tomorrow,"   Dialogue
# 44                                     said Scarlett.  Narrative
# 45  "It's rained\nnearly every day for a week.  Th...   Dialogue
# 47     "Oh, it'll be clear tomorrow and hot as June,"   Dialogue
# 48                                       said Stuart.  Narrative
# 49  "Look at that sunset.  I never saw one redder....   Dialogue
# 50  They looked out across the endless acres of Ge...  Narrative
# 51  "Be careful!  Be careful!  We had you once.  W...   Dialogue
# 52  To the ears of the three on the porch came the...  Narrative
# 53                                           "Yas'm,"   Dialogue
# 54  and there were sounds of footsteps going\nout ...  Narrative
# 55                 "Look, Scarlett.  About tomorrow,"   Dialogue
# 56                                        said Brent.  Narrative
# 57  "Just because\nwe've been away and didn't know...   Dialogue
# 59  "Well, I have!  How did I know you all would b...   Dialogue
# 61                                "You a wallflower!"   Dialogue
# 62                     The boys laughed uproariously.  Narrative

# %% [markdown]
# ##4. Match Entities between Dialogue Sections

# %%
def match_entities(text, text_type, characters):
    if text_type == "Narrative":
        ent_out = []
        for index, row in characters.iterrows():
            entity = row['character']
            matches = re.finditer(re.escape(entity), text)
            for match in matches:
                ent_out.append((match.start(), match.end(), row['character_real']))
        ent_out.sort(key=lambda x: x[0])
        #return all characters unless they were just mentioned before
        return [ent_out[i][2] for i in range(len(ent_out)) if i == 0 or ent_out[i][2] != ent_out[i - 1][2]]

    else:
        return None


result_df['Entities'] = result_df.apply(lambda row: match_entities(row['text'], row['type'], characters), axis=1)

# %%
result_df.head(n=50)
# Out:
#                                                  text       type  \
# 0   CHAPTER I\n\n\nScarlett O'Hara was not beautif...  Narrative
# 1   "I know you two don't care about being expelle...   Dialogue
# 2                                           she said.  Narrative
# 3   "But what about Boyd?  He's kind of set on get...   Dialogue
# 5   "Oh, he can read law in Judge Parmalee's offic...   Dialogue
# 6                          answered Brent carelessly.  Narrative
# 7   "Besides, it don't\nmatter much.  We'd have ha...   Dialogue
# 9                                              "Why?"   Dialogue
# 11  "The war, goose!  The war's going to start any...   Dialogue
# 13        "You know there isn't going to be any war,"   Dialogue
# 14                              said Scarlett, bored.  Narrative
# 15  "It's all just talk.  Why, Ashley Wilkes and h...   Dialogue
# 17                         "Not going to be any war!"   Dialogue
# 18  cried the twins indignantly, as though\nthey h...  Narrative
# 19  "Why, honey, of course there's going to be a w...   Dialogue
# 20                                       said Stuart.  Narrative
# 21  "The Yankees may be scared of us, but after th...   Dialogue
# 22         Scarlett made a mouth of bored impatience.  Narrative
# 23  "If you say 'war' just once more, I'll go in t...   Dialogue
# 24  She meant what she said, for she could never l...  Narrative
# 25  "What did your mother say about you two being ...   Dialogue
# 26  The boys looked uncomfortable, recalling their...  Narrative
# 27                                            "Well,"   Dialogue
# 28  said Stuart, "she hasn't had a chance to say a...  Narrative
# 29  "Didn't she say anything when you got home las...   Dialogue
# 31  "We were in luck last night.  Just before we g...   Dialogue
# 33                  "Do you suppose she'll hit Boyd?"   Dialogue
# 34  Scarlett, like the rest of the\nCounty, could ...  Narrative
# 35  "Of course she won't hit Boyd.  She never did ...   Dialogue
# 36            said Stuart, proud of his six feet two.  Narrative
# 37  "That's why we left him\nat home to explain th...   Dialogue
# 39  "Will your mother ride the new horse to the Wi...   Dialogue
# 41  "She wants to, but Pa says he's too dangerous....   Dialogue
# 43                 "I hope it doesn't rain tomorrow,"   Dialogue
# 44                                     said Scarlett.  Narrative
# 45  "It's rained\nnearly every day for a week.  Th...   Dialogue
# 47     "Oh, it'll be clear tomorrow and hot as June,"   Dialogue
# 48                                       said Stuart.  Narrative
# 49  "Look at that sunset.  I never saw one redder....   Dialogue
# 50  They looked out across the endless acres of Ge...  Narrative
# 51  "Be careful!  Be careful!  We had you once.  W...   Dialogue
# 52  To the ears of the three on the porch came the...  Narrative
# 53                                           "Yas'm,"   Dialogue
# 54  and there were sounds of footsteps going\nout ...  Narrative
# 55                 "Look, Scarlett.  About tomorrow,"   Dialogue
# 56                                        said Brent.  Narrative
# 57  "Just because\nwe've been away and didn't know...   Dialogue
# 59  "Well, I have!  How did I know you all would b...   Dialogue
# 61                                "You a wallflower!"   Dialogue
# 62                     The boys laughed uproariously.  Narrative
#
#                                              Entities
# 0   [Scarlett, Tarleton, Stuart, Brent, Tarleton, ...
# 1                                                None
# 2                                                  []
# 3                                                None
# 5                                                None
# 6                                             [Brent]
# 7                                                None
# 9                                                None
# 11                                               None
# 13                                               None
# 14                                         [Scarlett]
# 15                                               None
# 17                                               None
# 18                                                 []
# 19                                               None
# 20                                           [Stuart]
# 21                                               None
# 22                                         [Scarlett]
# 23                                               None
# 24                                                 []
# 25                                               None
# 26                                                 []
# 27                                               None
# 28                            [Stuart, Tom, Fontaine]
# 29                                               None
# 31                                               None
# 33                                               None
# 34           [Scarlett, Tarleton, Beatrice, Tarleton]
# 35                                               None
# 36                                           [Stuart]
# 37                                               None
# 39                                               None
# 41                                               None
# 43                                               None
# 44                                         [Scarlett]
# 45                                               None
# 47                                               None
# 48                                           [Stuart]
# 49                                               None
# 50                                           [Gerald]
# 51                                               None
# 52                                  [Scarlett, Ellen]
# 53                                               None
# 54                            [Ellen, Pork, Scarlett]
# 55                                               None
# 56                                            [Brent]
# 57                                               None
# 59                                               None
# 61                                               None
# 62                                                 []

# %%
convo_df =  pd.DataFrame(data = {
        'Character1': [],
        'Character2': [],
        'StartIndex': [],
        'EndIndex': [],
        'text_out': []
    })

convo_characters = []
convo_start = None
convo_end = None
text_out = ""
for idx, row in result_df.iterrows():
  if row['type'] == "Dialogue":
    convo_end = idx
    text_out += row['text']
    if convo_start is None:
      convo_start = idx

  else:
    if row['type'] == "Narrative":
      for entity in row['Entities']:
        if entity not in convo_characters and convo_characters is not None:
            convo_characters.append(entity)
        if len(convo_characters) > 2:
            new_row = pd.DataFrame(data= {'Character1': convo_characters[0], 'Character2': convo_characters[1], 'StartIndex': convo_start, 'EndIndex': convo_end, 'text_out': text_out}, index=[0])
            convo_df = pd.concat([convo_df, new_row])
            convo_characters = [convo_characters[-1]]
            convo_start = None
            text_out = ""

# %%
convo_df = convo_df.dropna()

# %%
def merge_characters(char1, char2):
  list_out = "_".join(sorted([char1, char2]))
  return str(list_out)

# %%
convo_df['characters'] = convo_df.apply(lambda row: merge_characters(row['Character1'], row['Character2']), axis=1)

# %%
convo_df['character_count'] = convo_df['text_out'].apply(len)

# %%
convo_df
# Out:
#    Character1 Character2 StartIndex EndIndex  \
# 0    Scarlett      Brent          1       19
# 0      Stuart   Scarlett         21       27
# 0         Tom   Fontaine         29       33
# 0    Beatrice   Tarleton         35       35
# 0      Stuart   Scarlett         37       49
# ..        ...        ...        ...      ...
# 0      Ashley   Scarlett      12887    12897
# 0       Rhett      Belle      12899    12911
# 0      Ashley      Rhett      12913    12947
# 0      Gerald      Rhett      12949    12971
# 0      Ashley      Rhett      12973    13007
#
#                                              text_out         characters  \
# 0   "I know you two don't care about being expelle...     Brent_Scarlett
# 0   "The Yankees may be scared of us, but after th...    Scarlett_Stuart
# 0   "Didn't she say anything when you got home las...       Fontaine_Tom
# 0   "Of course she won't hit Boyd.  She never did ...  Beatrice_Tarleton
# 0   "That's why we left him\nat home to explain th...    Scarlett_Stuart
# ..                                                ...                ...
# 0   "But love can't wear out!""Yours for Ashley di...    Ashley_Scarlett
# 0   "It was so obvious that we were meant for each...        Belle_Rhett
# 0   "But then, there was Bonnie and I saw that eve...       Ashley_Rhett
# 0   "Don't be a fool, Rhett!  I can make--""Don't ...       Gerald_Rhett
# 0   "A glamor to it--a perfection, a symmetry like...       Ashley_Rhett
#
#     character_count
# 0              1015
# 0               971
# 0              1302
# 0               126
# 0               714
# ..              ...
# 0              1702
# 0              2113
# 0              2358
# 0              1676
# 0              1796
#
# [1436 rows x 7 columns]

# %%
convo_df.groupby(['characters']).agg({'character_count': 'sum'}).sort_values(by='character_count', ascending=False).head(n=30).plot(kind = "bar")
# Out:
# <Axes: xlabel='characters'>

# %%
main_interactions  = ["Rhett_Scarlett", "Ashley_Scarlett", "Melanie_Scarlett", "Gerald_Scarlett"]

# %%
main_characters = ["Scarlett", "Rhett", "Ashley", "Gerald", "Melanie"]

# %%
convo_df_main = convo_df.loc[convo_df['characters'].isin(main_interactions), :].reset_index(drop = True)

# %%
convo_df.groupby(['characters']).agg({'character_count': 'count'}).sort_values(by='character_count', ascending=False).head(n=30).plot(kind = "bar")
# Out:
# <Axes: xlabel='characters'>

# %% [markdown]
# ## 5. Pre-process Text for Regressions and LDA

# %% [markdown]
# ### 5.1 Clean text from stopwords and other irrelevant words

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
df = pd.read_excel('possible_reduced_characters_v2 (1).xlsx', header=None)

# Filter the DataFrame to exclude rows where the third column contains "remove"
filtered_df = df[df.iloc[:, 2] != 'remove']

# Extract unique character names from the first column
character_names_all = filtered_df.iloc[:, 1].unique()

row_to_remove = 0
if row_to_remove < len(character_names_all):
    character_names_all = list(character_names_all)
    character_names_all.pop(row_to_remove)

# Print the extracted character names
print(character_names_all)
# Out:
# ['Rosa', 'Watling', 'Kill Ashley', 'Darcy', 'Ulster', 'Scarlert', 'Eugenie Victoria', 'Jeff\nDavis', 'Tell Mammy', 'Merriwether', 'Jack', 'Munroe', 'Scarlett', 'Mama Fontaine', 'Pauline', 'Dan Tucker', 'Unless Ashley', 'Buck Munroe', 'Fortunately Scarlett', 'Butler', 'Mick', 'Katie\nScarlett', 'Pharisees', 'Poke', 'Pitty', 'Big Sam', 'Sue', 'Bullock', 'Damn Prissy', 'Susan Elinor', 'Sarah Jane', 'Sam', 'Phil', 'Melly', 'Nathan Bedford Forrest', 'Sometimes Frank', 'Pierre Robillard', 'All Scarlett', 'Benteen', 'Bub', 'Mellie', 'Melanie', 'McRae', 'Johnson', 'Tarleton', 'Henry', 'Burdens', 'Paul Wilson', 'Generally Scarlett', 'Doc Fontaine', 'Dalton', 'Andy Bonnell', 'Suellen', 'Mammy, Cookie', 'Betsy', 'Small Carreen', 'Brown', 'Morgan', 'Wade', 'Calverts', 'Philip', 'Emmie', 'Kennedy', 'Jonas', 'Slattery', 'Betty', 'Bulloch', 'Off Scarlett', 'Calvert', 'Jane', 'Jerry', 'Dilcey', 'Mel--', 'Brenton', 'Yankee Hilton', 'Cathleen', 'Mees Scarlett', 'Tom', 'Mammy--Mammy', 'Wheeler', 'Alex.', 'Jim', 'Sylvia', 'Beau', 'Bonnie', 'Hefty Tarleton', 'Suzannah Talbot', "Break Melanie's", 'Elsing', 'Katie Scarlett', 'Lou', 'Boyne', 'Calhoun', 'Dolly Merriwether', 'Doctah Meade', 'Scallawag Butler', 'John', 'Stu', 'Frank', 'Caroline Irene', 'Ginger Whiskers', 'Except Suellen', 'Jeb Stuart', 'Papa', 'Hetty Tarleton', 'Hugh', 'Melissy', 'Priss', 'Bonnell', 'Robillard', 'Wilkerson', 'Grandfather\nRobillard', 'Ole Talbot', 'Beetrice', 'William', 'Maybelle', 'Hilton', 'Alex', 'Peter', 'Cathy', 'Johnston', 'Captain', 'Uncle', 'Boyd', 'James', 'Kennedy--', 'Andrew', 'Talbot', 'Leave Ashley', 'Susie', 'Ella Lorena', "Damn Ashley's", 'Sloan', 'Boo', 'Brent', 'Allan', 'Tommy', 'To Gerald', 'Rebecca', 'Mary', 'Davis', 'Aunt', 'Soon Mammy', 'Rhett--', 'Charles', 'Neither Ashley', 'Hamiltons', 'Ash', 'Archie', 'Ashley', 'Beatrice', 'Willie', "Hearing Melanie's", 'Mammy', 'Letty\nMunroe', 'Allison', 'Wellburn', 'Prudhomme', 'Should Ashley', 'Hampton', 'Nellie', "Dolly Merriwether's", 'Careen', "Jeb Stuart's", 'Mose', 'Toby', 'Swiftly Melanie', 'Wilkens', 'Frequently Rhett', 'Frankie Bonnell', 'Meade', 'Tony', 'Belle', 'Tomlinson', 'Put Phil', 'Bob Toombs', "Cap'n Butler", "Angus MacIntosh's", 'Merriwether--', 'Joe', 'Merriweather', 'Levi', 'Ellen', 'Medusa', 'Dean', 'Eulalie', 'Philippe', 'Dallas McLure', 'Nathan\nBedford Forrest', 'Johnnie', 'Pittypat', 'Charlie', 'Sally', 'Will', 'Bill', 'Fontaine', 'Davis--', 'Rhett', 'Gerald', 'Adam', 'Ryan', 'Gallic', 'Able Wynder', 'MacIntosh', 'Dimity Munroe', 'Tell Dilcey', 'Once Scarlett', 'Stuart', 'Kitty Bonnell', 'Lorena', 'Alice Munroe', 'Carreen', 'Jones', 'Gordon', 'Even Gerald', 'Sometimes Scarlett', "Seeing Gerald's", 'Mah\nDilcey', 'Raiford Calvert', 'Had Gerald', 'Sadie Belle', 'Wynder', 'Rene', 'Pork', 'India']

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

# Download stopwords if not already downloaded
nltk.download('stopwords')

# Manually add additional stopwords
additional_stopwords = [name.lower() for name in character_names_all]
custom_list_of_extra_stopwords = ["nt", "'s", "'m", "'ve", "'em", "'ll", "'t", "'d", "us", "'re", "theres", "therere", "theyd", "theyve"]
# Combine NLTK stopwords with additional stopwords
all_stopwords = set(stopwords.words('english') + custom_list_of_extra_stopwords)

# Define a function to remove stopwords from text
def remove_stopwords(text):
    # Tokenize the text
    punctuation_pattern = re.compile(r'[^\w\s]')
    # Remove punctuation marks from the text
    text = punctuation_pattern.sub('', text.lower())
    for substring in additional_stopwords:
        text = text.replace(substring, '')
    #text = regex.sub("", text.lower())
    #text = re.sub(characters_pattern, '', text)
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word.lower() in all_stopwords]
    # Join tokens back into a string
    filtered_text = ' '.join(tokens_without_sw)
    return filtered_text


# Assuming convo_df_main is your DataFrame and 'text_out' is the column containing text
# Apply the remove_stopwords function to the 'text_out' column
convo_df_main['text_out_processed'] = convo_df_main['text_out'].apply(remove_stopwords)

# Print the DataFrame to see the result
convo_df_main['text_out_processed'].head(60)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0                             careful careful take back
# 1     something important tell hardly know say itnot...
# 2                     none county touch statewell missy
# 3     reason bought asked buy herwell use buying goi...
# 4     twelve oaksabout usual cade settled set galler...
# 5     well speak uphe asked kindly sisters said hope...
# 6     im sorry daughter nothing child lots xmother f...
# 7     wish youd quit pushing dont want tara old plan...
# 8     youre young come love land getting away youre ...
# 9                      brat baptizedyes dead poor thing
# 10    ley hasnt idea im love himhow could know ive a...
# 11    getting another overseer wouldnt cheating eyet...
# 12    put tray come lace tighterand ill try eat litt...
# 13    ill remember tiful day till dieperhaps wedding...
# 14    mrs takes toss every huntand breaks collar bon...
# 15    drive well wear get horses yet course shes rig...
# 16           looks ifas knew looked like without shimmy
# 17    live barbecue till afternoonof course attentiv...
# 18    hes done well sit till midnightfort sumterof c...
# 19    fear agree mr thackerays works cynic fear gent...
# 20    lets dont hot headed lets dont war misery worl...
# 21                                 didnt reallywhat say
# 22    think acted fast girl could act todayeavesdrop...
# 23                                  well misshush honey
# 24    honey know isnt unkindit werent always busy lo...
# 25    come atlanta visit pat wont oh darling want mu...
# 26                                           baby house
# 27                                       sort ill admit
# 28                          want good time jine cavalry
# 29    shes stickand never popular like doesnt miss t...
# 30    least hospitali think go help make success thi...
# 31                                             im happy
# 32    know true scarlet dont mean little boys old ge...
# 33    husband wasnt afraid go neither id rather dead...
# 34    whyitsits mr isnt iti met youon happy occasion...
# 35    im quite righttheres need blow hair place darl...
# 36    husband dead longoh yes long time almost yeara...
# 37    pompous goat isnt hebut things enough good lad...
# 38    something youoh darlingyou brave brave girl wa...
# 39        hadnt brave enough would never eithername god
# 40    couldnt help seeing mrs eye time dear know tal...
# 41    another one perhapsnomrs hamiltoni tell imposs...
# 42    money told doesnt care anything confederacy sa...
# 43                                              darling
# 44    maybe wed better went occasionally parties may...
# 45    noquick smelling salts honey feel better breat...
# 46    illill help explain hospital surely hell under...
# 47    home would ever without youyoud glad without k...
# 48                                               cousin
# 49                          back went virginia next day
# 50    visiting dancing afterwards twins homewe heard...
# 51    oh miss sure didnt fast till baggage mine wink...
# 52                             young taken hanging tara
# 53                                llenbut thought mr oh
# 54    still pussyfoots afraid shadow ill asking inte...
# 55                                                missy
# 56    pa servantsthey know already sure everybody kn...
# 57    ill giving lament robert emmet tis song knowin...
# 58    lamentshe far land young hero sleeps lovers ro...
# 59                    hes father poor would die shed go
# Name: text_out_processed, dtype: object

# %%
convo_df_main
# Out:
#     Character1 Character2 StartIndex EndIndex  \
# 0       Gerald   Scarlett         51       51
# 1      Melanie   Scarlett        327      329
# 2       Gerald   Scarlett        335      337
# 3     Scarlett     Gerald        359      361
# 4     Scarlett     Gerald        363      373
# ..         ...        ...        ...      ...
# 298   Scarlett    Melanie      12637    12649
# 299    Melanie   Scarlett      12653    12653
# 300   Scarlett    Melanie      12733    12737
# 301   Scarlett      Rhett      12791    12885
# 302     Ashley   Scarlett      12887    12897
#
#                                               text_out        characters  \
# 0    "Be careful!  Be careful!  We had you once.  W...   Gerald_Scarlett
# 1    "Scarlett, I have something so important\nto t...  Melanie_Scarlett
# 2    "There's none in the County can touch you, nor...   Gerald_Scarlett
# 3    "And the only reason you\nbought her was becau...   Gerald_Scarlett
# 4    "How are they all over at Twelve Oaks?""About ...   Gerald_Scarlett
# ..                                                 ...               ...
# 298  "Good night,""Promise me--""Anything, darling....  Melanie_Scarlett
# 299       "Melly is the only woman friend I ever had,"  Melanie_Scarlett
# 300  "I don't want a word out of either of you.""I ...  Melanie_Scarlett
# 301  "So she's dead.  That makes it nice for you, d...    Rhett_Scarlett
# 302  "But love can't wear out!""Yours for Ashley di...   Ashley_Scarlett
#
#      character_count                                 text_out_processed
# 0                 73                          careful careful take back
# 1                173  something important tell hardly know say itnot...
# 2                 75                  none county touch statewell missy
# 3                306  reason bought asked buy herwell use buying goi...
# 4                748  twelve oaksabout usual cade settled set galler...
# ..               ...                                                ...
# 298              162  good nightpromise meanything darling kind helo...
# 299               44                                  woman friend ever
# 300              516  dont want word either youi mustnt cry front th...
# 301             3383  shes dead makes nice doesnt itoh say thingsyou...
# 302             1702  love cant wear outyours ley didbut never reall...
#
# [303 rows x 8 columns]

# %%
def count_tokens(text):
    # Split the text by whitespace to get tokens
    tokens = text.split()
    # Return the count of tokens
    return len(tokens)

# Apply the function to each row in the 'text_out_processed' column
convo_df_main['token_count'] = convo_df_main['text_out_processed'].apply(count_tokens)

# %%
convo_df_main
# Out:
#     Character1 Character2 StartIndex EndIndex  \
# 0       Gerald   Scarlett         51       51
# 1      Melanie   Scarlett        327      329
# 2       Gerald   Scarlett        335      337
# 3     Scarlett     Gerald        359      361
# 4     Scarlett     Gerald        363      373
# ..         ...        ...        ...      ...
# 298   Scarlett    Melanie      12637    12649
# 299    Melanie   Scarlett      12653    12653
# 300   Scarlett    Melanie      12733    12737
# 301   Scarlett      Rhett      12791    12885
# 302     Ashley   Scarlett      12887    12897
#
#                                               text_out        characters  \
# 0    "Be careful!  Be careful!  We had you once.  W...   Gerald_Scarlett
# 1    "Scarlett, I have something so important\nto t...  Melanie_Scarlett
# 2    "There's none in the County can touch you, nor...   Gerald_Scarlett
# 3    "And the only reason you\nbought her was becau...   Gerald_Scarlett
# 4    "How are they all over at Twelve Oaks?""About ...   Gerald_Scarlett
# ..                                                 ...               ...
# 298  "Good night,""Promise me--""Anything, darling....  Melanie_Scarlett
# 299       "Melly is the only woman friend I ever had,"  Melanie_Scarlett
# 300  "I don't want a word out of either of you.""I ...  Melanie_Scarlett
# 301  "So she's dead.  That makes it nice for you, d...    Rhett_Scarlett
# 302  "But love can't wear out!""Yours for Ashley di...   Ashley_Scarlett
#
#      character_count                                 text_out_processed  \
# 0                 73                          careful careful take back
# 1                173  something important tell hardly know say itnot...
# 2                 75                  none county touch statewell missy
# 3                306  reason bought asked buy herwell use buying goi...
# 4                748  twelve oaksabout usual cade settled set galler...
# ..               ...                                                ...
# 298              162  good nightpromise meanything darling kind helo...
# 299               44                                  woman friend ever
# 300              516  dont want word either youi mustnt cry front th...
# 301             3383  shes dead makes nice doesnt itoh say thingsyou...
# 302             1702  love cant wear outyours ley didbut never reall...
#
#      token_count
# 0              4
# 1             13
# 2              5
# 3             23
# 4             55
# ..           ...
# 298           11
# 299            3
# 300           51
# 301          293
# 302          148
#
# [303 rows x 9 columns]

# %%
import pandas as pd

# Assuming convo_df_main is your existing DataFrame

# Create a new DataFrame with only the specified columns
new_df = convo_df_main[['characters', 'token_count', 'text_out_processed']].copy()

# Display the new DataFrame
print(new_df)
# Out:
#            characters  token_count  \
# 0     Gerald_Scarlett            4
# 1    Melanie_Scarlett           13
# 2     Gerald_Scarlett            5
# 3     Gerald_Scarlett           23
# 4     Gerald_Scarlett           55
# ..                ...          ...
# 298  Melanie_Scarlett           11
# 299  Melanie_Scarlett            3
# 300  Melanie_Scarlett           51
# 301    Rhett_Scarlett          293
# 302   Ashley_Scarlett          148
#
#                                     text_out_processed
# 0                            careful careful take back
# 1    something important tell hardly know say itnot...
# 2                    none county touch statewell missy
# 3    reason bought asked buy herwell use buying goi...
# 4    twelve oaksabout usual cade settled set galler...
# ..                                                 ...
# 298  good nightpromise meanything darling kind helo...
# 299                                  woman friend ever
# 300  dont want word either youi mustnt cry front th...
# 301  shes dead makes nice doesnt itoh say thingsyou...
# 302  love cant wear outyours ley didbut never reall...
#
# [303 rows x 3 columns]

# %%
import pandas as pd

# Assuming new_df is your DataFrame containing the columns characters, token_count, and text_out_processed

# Counting rows where token_count is less than 9 or equal to 9
count = len(new_df[(new_df['token_count'] < 9) | (new_df['token_count'] == 9)])

print("Number of rows where token_count is less than 9 or equal to 9:", count)
# Out:
# Number of rows where token_count is less than 9 or equal to 9: 96

# %%
import pandas as pd

# Assuming new_df is your DataFrame containing the columns characters, token_count, and text_out_processed

# Filter rows where token_count is 9 or less
filtered_df = new_df[new_df['token_count'] <= 9]

# Count occurrences of each word in the "characters" column
word_counts = filtered_df['characters'].value_counts()

# Print the counts
print("Number of rows with 9 or less tokens for each word in 'characters' column:")
print(word_counts)
# Out:
# Number of rows with 9 or less tokens for each word in 'characters' column:
# characters
# Melanie_Scarlett    49
# Ashley_Scarlett     17
# Gerald_Scarlett     16
# Rhett_Scarlett      14
# Name: count, dtype: int64

# %%
# Get unique values in the "characters" column
unique_characters = new_df['characters'].unique()

# Create separate DataFrames with different variable names
for character in unique_characters:
    globals()[f'df_{character.replace(" ", "_")}'] = new_df[new_df['characters'] == character].copy()

# Now, you have separate DataFrames named df_Gerald_Scarlett, df_Melanie_Scarlett, df_Rhett_Scarlett, and df_Ashley_Scarlett

# %%
df_Gerald_Scarlett
# Out:
#           characters  token_count  \
# 0    Gerald_Scarlett            4
# 2    Gerald_Scarlett            5
# 3    Gerald_Scarlett           23
# 4    Gerald_Scarlett           55
# 5    Gerald_Scarlett           53
# 6    Gerald_Scarlett          276
# 7    Gerald_Scarlett           13
# 8    Gerald_Scarlett          148
# 9    Gerald_Scarlett            5
# 11   Gerald_Scarlett           35
# 14   Gerald_Scarlett           13
# 15   Gerald_Scarlett           37
# 16   Gerald_Scarlett            7
# 18   Gerald_Scarlett           48
# 50   Gerald_Scarlett           39
# 52   Gerald_Scarlett            4
# 54   Gerald_Scarlett           23
# 56   Gerald_Scarlett           78
# 57   Gerald_Scarlett           26
# 58   Gerald_Scarlett            9
# 59   Gerald_Scarlett            7
# 60   Gerald_Scarlett          166
# 104  Gerald_Scarlett           24
# 120  Gerald_Scarlett           73
# 133  Gerald_Scarlett            1
# 134  Gerald_Scarlett            4
# 136  Gerald_Scarlett            9
# 137  Gerald_Scarlett            4
# 138  Gerald_Scarlett          118
# 139  Gerald_Scarlett            2
# 142  Gerald_Scarlett           24
# 147  Gerald_Scarlett           50
# 148  Gerald_Scarlett            4
# 156  Gerald_Scarlett            7
# 172  Gerald_Scarlett            4
# 195  Gerald_Scarlett           25
# 202  Gerald_Scarlett          151
# 279  Gerald_Scarlett            2
#
#                                     text_out_processed
# 0                            careful careful take back
# 2                    none county touch statewell missy
# 3    reason bought asked buy herwell use buying goi...
# 4    twelve oaksabout usual cade settled set galler...
# 5    well speak uphe asked kindly sisters said hope...
# 6    im sorry daughter nothing child lots xmother f...
# 7    wish youd quit pushing dont want tara old plan...
# 8    youre young come love land getting away youre ...
# 9                     brat baptizedyes dead poor thing
# 11   getting another overseer wouldnt cheating eyet...
# 14   mrs takes toss every huntand breaks collar bon...
# 15   drive well wear get horses yet course shes rig...
# 16          looks ifas knew looked like without shimmy
# 18   hes done well sit till midnightfort sumterof c...
# 50   visiting dancing afterwards twins homewe heard...
# 52                            young taken hanging tara
# 54   still pussyfoots afraid shadow ill asking inte...
# 56   pa servantsthey know already sure everybody kn...
# 57   ill giving lament robert emmet tis song knowin...
# 58   lamentshe far land young hero sleeps lovers ro...
# 59                   hes father poor would die shed go
# 60   please go nowi seeing sunday dinnerwurra dayit...
# 104  dear daughter mother girls typhoid ill must ho...
# 120  darlingdont cry shall go home brave little gir...
# 133                                   daughterdaughter
# 134                       shes illi brought homecousin
# 136  get well pathe girls recoveringyour motherandm...
# 137                  didnt burn tarawhyyankeesin house
# 138  said would burning house heads three dying wom...
# 139                                          cruel war
# 142  tis thing world lasts anyone drop irish blood ...
# 147  wont work fields like darky cant make friends ...
# 148                     yankees already heremother god
# 156    damn yankeesand never expect call anything else
# 172                     layovers catch meddlersit must
# 195  fault brave like keeping ley home time mill oh...
# 202  ah thought dollar make eyes sparkle sure haven...
# 279                                           let stay

# %%
df_Melanie_Scarlett
# Out:
#            characters  token_count  \
# 1    Melanie_Scarlett           13
# 12   Melanie_Scarlett           15
# 19   Melanie_Scarlett           24
# 21   Melanie_Scarlett            3
# 22   Melanie_Scarlett           25
# ..                ...          ...
# 295  Melanie_Scarlett           53
# 296  Melanie_Scarlett           35
# 298  Melanie_Scarlett           11
# 299  Melanie_Scarlett            3
# 300  Melanie_Scarlett           51
#
#                                     text_out_processed
# 1    something important tell hardly know say itnot...
# 12   put tray come lace tighterand ill try eat litt...
# 19   fear agree mr thackerays works cynic fear gent...
# 21                                didnt reallywhat say
# 22   think acted fast girl could act todayeavesdrop...
# ..                                                 ...
# 295  must hold cant let get awayits promise meoh an...
# 296  leythank god know im worth thank letting knoww...
# 298  good nightpromise meanything darling kind helo...
# 299                                  woman friend ever
# 300  dont want word either youi mustnt cry front th...
#
# [126 rows x 3 columns]

# %%
df_Rhett_Scarlett
# Out:
#          characters  token_count  \
# 36   Rhett_Scarlett           21
# 37   Rhett_Scarlett           45
# 38   Rhett_Scarlett           12
# 41   Rhett_Scarlett           14
# 42   Rhett_Scarlett           32
# ..              ...          ...
# 289  Rhett_Scarlett           49
# 290  Rhett_Scarlett           23
# 291  Rhett_Scarlett           12
# 292  Rhett_Scarlett           97
# 301  Rhett_Scarlett          293
#
#                                     text_out_processed
# 36   husband dead longoh yes long time almost yeara...
# 37   pompous goat isnt hebut things enough good lad...
# 38   something youoh darlingyou brave brave girl wa...
# 41   another one perhapsnomrs hamiltoni tell imposs...
# 42   money told doesnt care anything confederacy sa...
# ..                                                 ...
# 289  wait till shes old enough hunttherell one like...
# 290  mother watch daddy says cani really must get a...
# 291  hush fool let go anyone want stay housenowdr t...
# 292  mrs wilkes ill come home immediatelyshe isntno...
# 301  shes dead makes nice doesnt itoh say thingsyou...
#
# [82 rows x 3 columns]

# %%
df_Ashley_Scarlett
# Out:
#           characters  token_count  \
# 10   Ashley_Scarlett           65
# 13   Ashley_Scarlett            8
# 17   Ashley_Scarlett           13
# 20   Ashley_Scarlett           15
# 26   Ashley_Scarlett            2
# 28   Ashley_Scarlett            5
# 61   Ashley_Scarlett            2
# 64   Ashley_Scarlett            1
# 78   Ashley_Scarlett           13
# 80   Ashley_Scarlett            9
# 95   Ashley_Scarlett          142
# 96   Ashley_Scarlett            2
# 97   Ashley_Scarlett            8
# 103  Ashley_Scarlett          238
# 143  Ashley_Scarlett            7
# 157  Ashley_Scarlett           20
# 166  Ashley_Scarlett            3
# 168  Ashley_Scarlett          474
# 169  Ashley_Scarlett           21
# 176  Ashley_Scarlett           20
# 179  Ashley_Scarlett           43
# 181  Ashley_Scarlett           90
# 182  Ashley_Scarlett           19
# 183  Ashley_Scarlett           17
# 184  Ashley_Scarlett          296
# 185  Ashley_Scarlett          120
# 187  Ashley_Scarlett           48
# 188  Ashley_Scarlett           16
# 190  Ashley_Scarlett           44
# 192  Ashley_Scarlett           15
# 193  Ashley_Scarlett           88
# 196  Ashley_Scarlett           65
# 199  Ashley_Scarlett           25
# 200  Ashley_Scarlett           85
# 201  Ashley_Scarlett            8
# 203  Ashley_Scarlett          393
# 206  Ashley_Scarlett            4
# 213  Ashley_Scarlett            5
# 215  Ashley_Scarlett           12
# 224  Ashley_Scarlett            5
# 247  Ashley_Scarlett            2
# 255  Ashley_Scarlett           79
# 257  Ashley_Scarlett          195
# 258  Ashley_Scarlett           85
# 259  Ashley_Scarlett            4
# 261  Ashley_Scarlett           97
# 265  Ashley_Scarlett           30
# 266  Ashley_Scarlett           22
# 274  Ashley_Scarlett           46
# 280  Ashley_Scarlett           47
# 281  Ashley_Scarlett           10
# 282  Ashley_Scarlett           48
# 284  Ashley_Scarlett          103
# 293  Ashley_Scarlett           60
# 294  Ashley_Scarlett            7
# 297  Ashley_Scarlett           11
# 302  Ashley_Scarlett          148
#
#                                     text_out_processed
# 10   ley hasnt idea im love himhow could know ive a...
# 13   ill remember tiful day till dieperhaps wedding...
# 17   live barbecue till afternoonof course attentiv...
# 20   lets dont hot headed lets dont war misery worl...
# 26                                          baby house
# 28                         want good time jine cavalry
# 61                                           dear wife
# 64                                               dixie
# 78   forgive saying know love arent mad youdont sil...
# 80   gentlemen georgia troops well cant get along w...
# 95   perhaps old march ride shoot mrs kindly lent w...
# 96                                             god ley
# 97        news newsdont know fer sartin lady soon tell
# 103  couldnt tonight boy homewhat luckdont giggledo...
# 143  whywhyshes like understands feelshed done e thing
# 157  mrs wilkes dont bother husbandi captured first...
# 166                                beloved coming home
# 168  hes skunk ever one whats become alli wonderi w...
# 169  nothing leftnothing left nothing love nothing ...
# 176  ahthats difference even though theyre poor sti...
# 179  loved hell permit come atlanta get tax money i...
# 181  thing wanted tell mewhat change subject baring...
# 182  figger way pa gone nun therell llen left cours...
# 183  tiful voice anyone pa im glad ley id rather pr...
# 184  never said wasnt hes helpless turtle back wilk...
# 185  leyyou must come atlanta need help badly cant ...
# 187  manageri offered half interest heand told alre...
# 188  ley could refuse shes done ungrateful make app...
# 190  oh talked going new york thought nothing atlan...
# 192  thank e darling would crowd well get house oh ...
# 193  england recognized usif jeff commandeered cott...
# 196  youll nothing kind earthly good would ley work...
# 199  amendment letting darkies vote knowit submitte...
# 200  itll make things much harder usoh ley surely t...
# 201         tell whats worrying ill fix ill make right
# 203  happy dr father father happywell perhaps happy...
# 206                     military district number three
# 213                          ive killed ley ive killed
# 215  hell hellthat cant leyhe never gets drunk drun...
# 224                     plenty could tell ley precious
# 247                                          beds dear
# 255  downtown time day arent house helping get read...
# 257  hate hear talk like leyyou sound like hes alwa...
# 258  shouldnt let make look backi right said id nev...
# 259                        dont believe anything wrong
# 261  nowi interested explanations know truth better...
# 265  come filthy lies concocted mrs dare course mrs...
# 266  shes always jeas loved best dear shell never c...
# 274  course settled secretbut never kept anything s...
# 280  wants buy outyes course told wouldnt selli wis...
# 281  anything thisiyou know better never go world g...
# 282  lost mindyoull lose money lease kind labor get...
# 284  im afraid people say long im right never felt ...
# 293  train isnt really tell shes better isnt ley sp...
# 294      finally got herenot yetshe wants speak doctor
# 297  youre smartso bravealways good meive devil ive...
# 302  love cant wear outyours ley didbut never reall...

# %%
import pandas as pd

# List of DataFrames
dataframes = [df_Ashley_Scarlett, df_Rhett_Scarlett, df_Gerald_Scarlett, df_Melanie_Scarlett]
for df in dataframes:
    # Drop the 'characters' column
    df.drop(columns=['characters'], inplace=True)

    # Reset the index
    df.reset_index(drop=True, inplace=True)

    # Print the DataFrame after removing the 'characters' column and resetting the index
    print(df)
# Out:
#     token_count                                 text_out_processed
# 0            65  ley hasnt idea im love himhow could know ive a...
# 1             8  ill remember tiful day till dieperhaps wedding...
# 2            13  live barbecue till afternoonof course attentiv...
# 3            15  lets dont hot headed lets dont war misery worl...
# 4             2                                         baby house
# 5             5                        want good time jine cavalry
# 6             2                                          dear wife
# 7             1                                              dixie
# 8            13  forgive saying know love arent mad youdont sil...
# 9             9  gentlemen georgia troops well cant get along w...
# 10          142  perhaps old march ride shoot mrs kindly lent w...
# 11            2                                            god ley
# 12            8       news newsdont know fer sartin lady soon tell
# 13          238  couldnt tonight boy homewhat luckdont giggledo...
# 14            7  whywhyshes like understands feelshed done e thing
# 15           20  mrs wilkes dont bother husbandi captured first...
# 16            3                                beloved coming home
# 17          474  hes skunk ever one whats become alli wonderi w...
# 18           21  nothing leftnothing left nothing love nothing ...
# 19           20  ahthats difference even though theyre poor sti...
# 20           43  loved hell permit come atlanta get tax money i...
# 21           90  thing wanted tell mewhat change subject baring...
# 22           19  figger way pa gone nun therell llen left cours...
# 23           17  tiful voice anyone pa im glad ley id rather pr...
# 24          296  never said wasnt hes helpless turtle back wilk...
# 25          120  leyyou must come atlanta need help badly cant ...
# 26           48  manageri offered half interest heand told alre...
# 27           16  ley could refuse shes done ungrateful make app...
# 28           44  oh talked going new york thought nothing atlan...
# 29           15  thank e darling would crowd well get house oh ...
# 30           88  england recognized usif jeff commandeered cott...
# 31           65  youll nothing kind earthly good would ley work...
# 32           25  amendment letting darkies vote knowit submitte...
# 33           85  itll make things much harder usoh ley surely t...
# 34            8         tell whats worrying ill fix ill make right
# 35          393  happy dr father father happywell perhaps happy...
# 36            4                     military district number three
# 37            5                          ive killed ley ive killed
# 38           12  hell hellthat cant leyhe never gets drunk drun...
# 39            5                     plenty could tell ley precious
# 40            2                                          beds dear
# 41           79  downtown time day arent house helping get read...
# 42          195  hate hear talk like leyyou sound like hes alwa...
# 43           85  shouldnt let make look backi right said id nev...
# 44            4                        dont believe anything wrong
# 45           97  nowi interested explanations know truth better...
# 46           30  come filthy lies concocted mrs dare course mrs...
# 47           22  shes always jeas loved best dear shell never c...
# 48           46  course settled secretbut never kept anything s...
# 49           47  wants buy outyes course told wouldnt selli wis...
# 50           10  anything thisiyou know better never go world g...
# 51           48  lost mindyoull lose money lease kind labor get...
# 52          103  im afraid people say long im right never felt ...
# 53           60  train isnt really tell shes better isnt ley sp...
# 54            7      finally got herenot yetshe wants speak doctor
# 55           11  youre smartso bravealways good meive devil ive...
# 56          148  love cant wear outyours ley didbut never reall...
#     token_count                                 text_out_processed
# 0            21  husband dead longoh yes long time almost yeara...
# 1            45  pompous goat isnt hebut things enough good lad...
# 2            12  something youoh darlingyou brave brave girl wa...
# 3            14  another one perhapsnomrs hamiltoni tell imposs...
# 4            32  money told doesnt care anything confederacy sa...
# ..          ...                                                ...
# 77           49  wait till shes old enough hunttherell one like...
# 78           23  mother watch daddy says cani really must get a...
# 79           12  hush fool let go anyone want stay housenowdr t...
# 80           97  mrs wilkes ill come home immediatelyshe isntno...
# 81          293  shes dead makes nice doesnt itoh say thingsyou...
#
# [82 rows x 2 columns]
#     token_count                                 text_out_processed
# 0             4                          careful careful take back
# 1             5                  none county touch statewell missy
# 2            23  reason bought asked buy herwell use buying goi...
# 3            55  twelve oaksabout usual cade settled set galler...
# 4            53  well speak uphe asked kindly sisters said hope...
# 5           276  im sorry daughter nothing child lots xmother f...
# 6            13  wish youd quit pushing dont want tara old plan...
# 7           148  youre young come love land getting away youre ...
# 8             5                   brat baptizedyes dead poor thing
# 9            35  getting another overseer wouldnt cheating eyet...
# 10           13  mrs takes toss every huntand breaks collar bon...
# 11           37  drive well wear get horses yet course shes rig...
# 12            7         looks ifas knew looked like without shimmy
# 13           48  hes done well sit till midnightfort sumterof c...
# 14           39  visiting dancing afterwards twins homewe heard...
# 15            4                           young taken hanging tara
# 16           23  still pussyfoots afraid shadow ill asking inte...
# 17           78  pa servantsthey know already sure everybody kn...
# 18           26  ill giving lament robert emmet tis song knowin...
# 19            9  lamentshe far land young hero sleeps lovers ro...
# 20            7                  hes father poor would die shed go
# 21          166  please go nowi seeing sunday dinnerwurra dayit...
# 22           24  dear daughter mother girls typhoid ill must ho...
# 23           73  darlingdont cry shall go home brave little gir...
# 24            1                                   daughterdaughter
# 25            4                       shes illi brought homecousin
# 26            9  get well pathe girls recoveringyour motherandm...
# 27            4                  didnt burn tarawhyyankeesin house
# 28          118  said would burning house heads three dying wom...
# 29            2                                          cruel war
# 30           24  tis thing world lasts anyone drop irish blood ...
# 31           50  wont work fields like darky cant make friends ...
# 32            4                     yankees already heremother god
# 33            7    damn yankeesand never expect call anything else
# 34            4                     layovers catch meddlersit must
# 35           25  fault brave like keeping ley home time mill oh...
# 36          151  ah thought dollar make eyes sparkle sure haven...
# 37            2                                           let stay
#      token_count                                 text_out_processed
# 0             13  something important tell hardly know say itnot...
# 1             15  put tray come lace tighterand ill try eat litt...
# 2             24  fear agree mr thackerays works cynic fear gent...
# 3              3                               didnt reallywhat say
# 4             25  think acted fast girl could act todayeavesdrop...
# ..           ...                                                ...
# 121           53  must hold cant let get awayits promise meoh an...
# 122           35  leythank god know im worth thank letting knoww...
# 123           11  good nightpromise meanything darling kind helo...
# 124            3                                  woman friend ever
# 125           51  dont want word either youi mustnt cry front th...
#
# [126 rows x 2 columns]

# %%
num_rows = df_Ashley_Scarlett.shape[0]
print("Number of rows in df_Ashley_Scarlett:", num_rows)
# Out:
# Number of rows in df_Ashley_Scarlett: 57

# %%
num_rows = df_Rhett_Scarlett.shape[0]
print("Number of rows in df_Rhett_Scarlett:", num_rows)
# Out:
# Number of rows in df_Rhett_Scarlett: 82

# %%
num_rows = df_Gerald_Scarlett.shape[0]
print("Number of rows in df_Gerald_Scarlett:", num_rows)
# Out:
# Number of rows in df_Gerald_Scarlett: 38

# %%
num_rows = df_Melanie_Scarlett.shape[0]
print("Number of rows in df_Melanie_Scarlett:", num_rows)
# Out:
# Number of rows in df_Melanie_Scarlett: 126

# %%
import pandas as pd

def combine_text(df):
    # Group the DataFrame into groups of 10 consecutive rows
    grouped = df.groupby(df.index // 10)

    # Aggregate each group into a single row by concatenating the text
    combined_df = grouped.agg({'text_out_processed': ' '.join, 'token_count': 'sum'}).reset_index(drop=True)

    return combined_df

# Assuming df_Ashley_Scarlett1, df_Ashley_Scarlett2, df_Ashley_Scarlett3, and df_Ashley_Scarlett4 are your dataframes
# Replace these with your actual dataframe names

# Apply the combine_text function to each dataframe
combined_df_Ashley = combine_text(df_Ashley_Scarlett)
combined_df_Rhett = combine_text(df_Rhett_Scarlett)
combined_df_Melanie = combine_text(df_Melanie_Scarlett)
combined_df_Gerald = combine_text(df_Gerald_Scarlett)

# Print the combined DataFrames
print(combined_df_Ashley)
print(combined_df_Rhett)
print(combined_df_Melanie)
print(combined_df_Gerald)
# Out:
#                                   text_out_processed  token_count
# 0  ley hasnt idea im love himhow could know ive a...          133
# 1  perhaps old march ride shoot mrs kindly lent w...          935
# 2  loved hell permit come atlanta get tax money i...          708
# 3  england recognized usif jeff commandeered cott...          690
# 4  beds dear downtown time day arent house helpin...          607
# 5  anything thisiyou know better never go world g...          387
#                                   text_out_processed  token_count
# 0  husband dead longoh yes long time almost yeara...          970
# 1  air hungrythere wont crop yearthere aint nobod...         1097
# 2  put damn put walk oh would ever done without i...         1818
# 3  god discuss expect answer hes still love youwe...         1752
# 4  stranger without told word would know house bu...          266
# 5  man world wouldnt care much ive seen hes done ...          383
# 6  sat chestwas big oneoh yes dretfull big clawsa...          539
# 7  ragamuffin im sorryis everything rightdid get ...          359
# 8  mrs wilkes ill come home immediatelyshe isntno...          390
#                                    text_out_processed  token_count
# 0   something important tell hardly know say itnot...          163
# 1   least hospitali think go help make success thi...          321
# 2   noquick smelling salts honey feel better breat...          151
# 3   dew blossomoh lawd ladies dont mind stephen in...          520
# 4   ley careful wont youplease dont get feet wet t...          179
# 5   close wasnt itm abject apologies dirbing could...          412
# 6   gods sake dont try brave yell want nobody hear...           84
# 7   dearare homenot yetpoor babyget cousin home tw...          419
# 8   look like end man minstrel showwhy hit mebecau...          252
# 9   poor im sorry laughed really truly forgive mis...          247
# 10  oh hush ie youre tactlessoh dear think know hu...          386
# 11  ahhow sweet worried poor take single drink tim...          270
# 12  money made happy hasnt darling must hold cant ...          158
#                                   text_out_processed  token_count
# 0  careful careful take back none county touch st...          617
# 1  mrs takes toss every huntand breaks collar bon...          284
# 2  hes father poor would die shed go please go no...          408
# 3  tis thing world lasts anyone drop irish blood ...          267

# %%
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# Assuming you have a DataFrame named combined_df_Melanie with 'text_out_processed' column
# Extract text data from the DataFrame
data = combined_df_Melanie['text_out_processed'].apply(lambda x: x.split())

# Create a dictionary from the preprocessed data
dictionary = Dictionary(data)

# Filter out words that appear in fewer than 5 documents or more than 50% of the documents
dictionary.filter_extremes(no_below=5, no_above=0.5)

# Convert the preprocessed text data into bag-of-words format
bow_corpus = [dictionary.doc2bow(text) for text in data]

# Train the LDA model
num_topics = 5
ldamodel = LdaModel(bow_corpus, num_topics=num_topics, id2word=dictionary, passes=20, alpha='auto', eta='auto')

# Get the topics
topics = ldamodel.show_topics(num_topics=num_topics, num_words=10, log=False, formatted=False)

# Print the topics
for topic_id, topic in topics:
    print("Topic: {}".format(topic_id))
    print("Words: {}".format([word for word, _ in topic]))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Topic: 0
# Words: ['wouldnt', 'really', 'thought', 'mr', 'something', 'back', 'sweet', 'feel', 'make', 'poor']
# Topic: 1
# Words: ['back', 'baby', 'id', 'came', 'wouldnt', 'done', 'care', 'give', 'thought', 'little']
# Topic: 2
# Words: ['baby', 'mustnt', 'afraid', 'dead', 'today', 'ive', 'id', 'mrs', 'talk', 'look']
# Topic: 3
# Words: ['make', 'mr', 'bring', 'mrs', 'mean', 'husband', 'things', 'little', 'men', 'house']
# Topic: 4
# Words: ['mrs', 'help', 'something', 'thought', 'id', 'old', 'things', 'baby', 'came', 'really']

# %%
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# Assuming you have a DataFrame named combined_df_Melanie with 'text_out_processed' column
texts = combined_df_Melanie['text_out_processed'].apply(lambda x: x.split())

all_topics = []

# Iterate through each row and apply LDA
for text in texts:
    # Create a dictionary from the preprocessed data
    dictionary = Dictionary([text])

    # Convert the preprocessed text data into bag-of-words format
    bow_corpus = [dictionary.doc2bow(text)]

    # Train the LDA model
    num_topics = 5
    ldamodel = LdaModel(bow_corpus, num_topics=num_topics, id2word=dictionary, passes=20, alpha='auto', eta='auto')

    # Get the topics
    topics = ldamodel.show_topics(num_topics=num_topics, num_words=10, log=False, formatted=False)

    # Extract top words for each topic
    text_topics = []
    for topic_id, topic in topics:
        text_topics.append([word for word, _ in topic])

    all_topics.append(text_topics)

# Print the topics for each text
for idx, topics in enumerate(all_topics):
    print(f"Text {idx + 1} Topics:")
    for topic_id, topic_words in enumerate(topics):
        print(f"Topic {topic_id + 1}: {topic_words}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# Text 1 Topics:
# Topic 1: ['got', 'know', 'think', 'get', 'honey', 'little', 'mr', 'lace', 'want', 'shes']
# Topic 2: ['know', 'shes', 'want', 'mr', 'little', 'think', 'got', 'honey', 'fear', 'ever']
# Topic 3: ['shes', 'think', 'mr', 'honey', 'little', 'know', 'get', 'want', 'got', 'didnt']
# Topic 4: ['know', 'mr', 'get', 'think', 'shes', 'little', 'honey', 'got', 'want', 'home']
# Topic 5: ['know', 'want', 'honey', 'little', 'got', 'shes', 'get', 'think', 'mr', 'ley']
# Text 2 Topics:
# Topic 1: ['mrs', 'go', 'think', 'dont', 'im', 'quite', 'know', 'lead', 'must', 'hospital']
# Topic 2: ['think', 'go', 'hospital', 'must', 'mrs', 'im', 'enough', 'quite', 'like', 'know']
# Topic 3: ['think', 'go', 'quite', 'know', 'must', 'mrs', 'im', 'hospital', 'lady', 'darling']
# Topic 4: ['think', 'go', 'quite', 'hospital', 'im', 'know', 'well', 'must', 'dont', 'lead']
# Topic 5: ['think', 'know', 'go', 'im', 'must', 'hospital', 'mrs', 'quite', 'lady', 'well']
# Text 3 Topics:
# Topic 1: ['oh', 'didnt', 'home', 'alarmed', 'thoughts', 'go', 'ask', 'think', 'im', 'dear']
# Topic 2: ['oh', 'without', 'heart', 'wife', 'dear', 'ask', 'thoughts', 'back', 'think', 'home']
# Topic 3: ['oh', 'im', 'think', 'go', 'heart', 'alarmed', 'dear', 'without', 'ask', 'thoughts']
# Topic 4: ['back', 'alarmed', 'didnt', 'oh', 'heart', 'home', 'wife', 'thoughts', 'go', 'think']
# Topic 5: ['oh', 'dear', 'wife', 'back', 'im', 'didnt', 'home', 'go', 'ask', 'without']
# Text 4 Topics:
# Topic 1: ['said', 'know', 'cant', 'oh', 'hospital', 'could', 'money', 'dont', 'tell', 'think']
# Topic 2: ['know', 'said', 'money', 'oh', 'think', 'could', 'dont', 'cant', 'tell', 'hospital']
# Topic 3: ['said', 'know', 'oh', 'cant', 'money', 'think', 'something', 'ley', 'hospital', 'dont']
# Topic 4: ['said', 'dont', 'oh', 'cant', 'think', 'know', 'money', 'tell', 'bad', 'hospital']
# Topic 5: ['said', 'dont', 'oh', 'know', 'think', 'money', 'cant', 'could', 'tell', 'hospital']
# Text 5 Topics:
# Topic 1: ['oh', 'know', 'dont', 'dead', 'darling', 'got', 'ive', 'never', 'look', 'oath']
# Topic 2: ['darling', 'dont', 'oh', 'baby', 'ive', 'dead', 'got', 'id', 'know', 'like']
# Topic 3: ['know', 'oh', 'baby', 'got', 'dead', 'ive', 'dont', 'darling', 'would', 'id']
# Topic 4: ['know', 'oh', 'ive', 'darling', 'dont', 'baby', 'dead', 'never', 'look', 'got']
# Topic 5: ['darling', 'oh', 'know', 'ive', 'got', 'dead', 'baby', 'never', 'dont', 'said']
# Text 6 Topics:
# Topic 1: ['baby', 'im', 'know', 'promise', 'take', 'get', 'today', 'right', 'send', 'die']
# Topic 2: ['baby', 'get', 'die', 'im', 'know', 'today', 'mrs', 'send', 'right', 'think']
# Topic 3: ['get', 'baby', 'know', 'die', 'im', 'take', 'today', 'promise', 'think', 'send']
# Topic 4: ['baby', 'die', 'know', 'im', 'get', 'take', 'send', 'promise', 'today', 'please']
# Topic 5: ['baby', 'im', 'die', 'know', 'today', 'mother', 'get', 'send', 'oh', 'ley']
# Text 7 Topics:
# Topic 1: ['dont', 'think', 'get', 'talk', 'hush', 'im', 'well', 'please', 'hurry', 'yankees']
# Topic 2: ['dont', 'get', 'think', 'going', 'mustnt', 'leave', 'yankees', 'please', 'hurry', 'well']
# Topic 3: ['dont', 'think', 'get', 'going', 'im', 'hurry', 'yankees', 'well', 'hush', 'leave']
# Topic 4: ['dont', 'yankees', 'think', 'talk', 'get', 'well', 'hurry', 'leave', 'going', 'please']
# Topic 5: ['dont', 'think', 'get', 'talk', 'im', 'going', 'hurry', 'hush', 'well', 'please']
# Text 8 Topics:
# Topic 1: ['must', 'get', 'ill', 'go', 'back', 'dont', 'folks', 'dear', 'let', 'take']
# Topic 2: ['ill', 'must', 'dont', 'get', 'back', 'go', 'kill', 'drag', 'dear', 'well']
# Topic 3: ['ill', 'get', 'must', 'go', 'dont', 'back', 'kill', 'take', 'folks', 'know']
# Topic 4: ['ill', 'get', 'must', 'back', 'go', 'take', 'come', 'kill', 'dont', 'well']
# Topic 5: ['ill', 'get', 'go', 'must', 'take', 'dont', 'back', 'done', 'kill', 'know']
# Text 9 Topics:
# Topic 1: ['back', 'yankees', 'come', 'wouldnt', 'cant', 'dont', 'know', 'leave', 'everything', 'go']
# Topic 2: ['yankees', 'cant', 'back', 'wouldnt', 'come', 'everything', 'go', 'oh', 'enough', 'look']
# Topic 3: ['yankees', 'back', 'leave', 'know', 'go', 'everything', 'dont', 'cry', 'cant', 'wouldnt']
# Topic 4: ['back', 'yankees', 'come', 'go', 'wouldnt', 'dont', 'cant', 'leave', 'everything', 'know']
# Topic 5: ['back', 'yankees', 'wouldnt', 'cant', 'come', 'know', 'thing', 'everything', 'sing', 'mean']
# Text 10 Topics:
# Topic 1: ['oh', 'think', 'ley', 'home', 'dont', 'done', 'got', 'maybe', 'need', 'know']
# Topic 2: ['oh', 'home', 'think', 'ley', 'got', 'dont', 'done', 'time', 'ill', 'north']
# Topic 3: ['oh', 'think', 'ley', 'dont', 'home', 'done', 'got', 'north', 'come', 'poor']
# Topic 4: ['oh', 'ley', 'think', 'home', 'dont', 'done', 'killed', 'got', 'come', 'good']
# Topic 5: ['oh', 'home', 'ley', 'think', 'dont', 'got', 'done', 'time', 'came', 'yankee']
# Text 11 Topics:
# Topic 1: ['forget', 'make', 'people', 'house', 'men', 'oh', 'must', 'im', 'know', 'mean']
# Topic 2: ['know', 'forget', 'love', 'must', 'men', 'house', 'oh', 'dont', 'im', 'people']
# Topic 3: ['forget', 'make', 'governor', 'people', 'love', 'even', 'dont', 'dear', 'men', 'must']
# Topic 4: ['forget', 'make', 'people', 'even', 'hurt', 'youre', 'love', 'place', 'dont', 'know']
# Topic 5: ['make', 'forget', 'must', 'hurt', 'even', 'mean', 'im', 'men', 'dear', 'people']
# Text 12 Topics:
# Topic 1: ['never', 'well', 'believe', 'dont', 'going', 'wouldnt', 'shes', 'hasnt', 'hold', 'im']
# Topic 2: ['well', 'believe', 'never', 'hold', 'wouldnt', 'shes', 'would', 'hasnt', 'going', 'good']
# Topic 3: ['well', 'never', 'believe', 'shes', 'dont', 'wouldnt', 'hasnt', 'good', 'understand', 'going']
# Topic 4: ['well', 'believe', 'hold', 'never', 'shes', 'understand', 'home', 'hasnt', 'birthday', 'going']
# Topic 5: ['never', 'well', 'hasnt', 'going', 'dont', 'believe', 'birthday', 'shes', 'wouldnt', 'youre']
# Text 13 Topics:
# Topic 1: ['know', 'ill', 'ley', 'let', 'cant', 'ever', 'begin', 'load', 'kind', 'youi']
# Topic 2: ['know', 'ill', 'let', 'load', 'ley', 'cry', 'talk', 'ever', 'oh', 'mustnt']
# Topic 3: ['know', 'ill', 'ley', 'let', 'load', 'youi', 'kind', 'weary', 'like', 'promise']
# Topic 4: ['ill', 'know', 'load', 'ley', 'let', 'dont', 'mustnt', 'youi', 'meoh', 'like']
# Topic 5: ['ill', 'know', 'load', 'ley', 'promise', 'must', 'let', 'darling', 'god', 'like']

# %% [markdown]
# to delete:

# %%
import pandas as pd
import random

def combine_dataframes(df, name):
    # Separate into two DataFrames based on token count
    df_less_than_10 = df[df['token_count'] < 10]
    df_10_or_more = df[df['token_count'] >= 10]

    # Initialize a new DataFrame to store the combined rows
    combined_df = pd.DataFrame(columns=["characters", "token_count", "text_out_processed"])

    # Combine rows with less than 10 tokens until each combined group has 10 or more tokens
    combined_texts = []
    while len(df_less_than_10) > 0:
        combined_text = ""
        combined_tokens = 0
        while combined_tokens < 10 and len(df_less_than_10) > 0:
            idx = random.choice(df_less_than_10.index)
            text = df_less_than_10.loc[idx, "text_out_processed"]
            token_count = df_less_than_10.loc[idx, "token_count"]
            combined_text += " " + text
            combined_tokens += token_count
            df_less_than_10 = df_less_than_10.drop(idx)
        combined_texts.append(combined_text.strip())

    # Add combined texts to the new DataFrame
    combined_df["text_out_processed"] = combined_texts
    combined_df["token_count"] = combined_df["text_out_processed"].apply(lambda x: len(x.split()))
    combined_df["characters"] = df.iloc[0]["characters"]  # Assuming each DataFrame has a "characters" column

    # Append rows with 10 or more tokens to the end of the new DataFrame
    combined_df = pd.concat([combined_df, df_10_or_more])

    # Reset index
    combined_df.reset_index(drop=True, inplace=True)

    # Dynamically assign name to the resulting DataFrame
    combined_df.name = name

    return combined_df

# List of DataFrames with corresponding names
dfs_and_names = [(df_Rhett_Scarlett, "combined_df_Rhett"),
                 (df_Ashley_Scarlett, "combined_df_Ashley"),
                 (df_Gerald_Scarlett, "combined_df_Gerald"),
                 (df_Melanie_Scarlett, "combined_df_Melanie")]

# Apply the combine_dataframes function to each DataFrame and assign the resulting DataFrame to a variable with the specified name
for df, name in dfs_and_names:
    locals()[name] = combine_dataframes(df, name)

# Print or use the combined DataFrames as needed
print(combined_df_Rhett)
print(combined_df_Ashley)
print(combined_df_Gerald)
print(combined_df_Melanie)
# Out:
#         characters  token_count  \
# 0   Rhett_Scarlett           12
# 1   Rhett_Scarlett           14
# 2   Rhett_Scarlett           12
# 3   Rhett_Scarlett           16
# 4   Rhett_Scarlett            7
# ..             ...          ...
# 68  Rhett_Scarlett           49
# 69  Rhett_Scarlett           23
# 70  Rhett_Scarlett           12
# 71  Rhett_Scarlett           97
# 72  Rhett_Scarlett          293
#
#                                    text_out_processed
# 0   youre fine honest rogue trying devil ragamuffi...
# 1   know everyone thinks child smart oh would ever...
# 2   consistency thou art jewel youd never wake unl...
# 3   old guard want put damn put walk wont work con...
# 4      dark hurry tell dysenterycome ill show wounded
# ..                                                ...
# 68  wait till shes old enough hunttherell one like...
# 69  mother watch daddy says cani really must get a...
# 70  hush fool let go anyone want stay housenowdr t...
# 71  mrs wilkes ill come home immediatelyshe isntno...
# 72  shes dead makes nice doesnt itoh say thingsyou...
#
# [73 rows x 3 columns]
#          characters  token_count  \
# 0   Ashley_Scarlett           14
# 1   Ashley_Scarlett           12
# 2   Ashley_Scarlett           17
# 3   Ashley_Scarlett           14
# 4   Ashley_Scarlett           12
# 5   Ashley_Scarlett           13
# 6   Ashley_Scarlett           65
# 7   Ashley_Scarlett           13
# 8   Ashley_Scarlett           15
# 9   Ashley_Scarlett           13
# 10  Ashley_Scarlett          142
# 11  Ashley_Scarlett          238
# 12  Ashley_Scarlett           20
# 13  Ashley_Scarlett          474
# 14  Ashley_Scarlett           21
# 15  Ashley_Scarlett           20
# 16  Ashley_Scarlett           43
# 17  Ashley_Scarlett           90
# 18  Ashley_Scarlett           19
# 19  Ashley_Scarlett           17
# 20  Ashley_Scarlett          296
# 21  Ashley_Scarlett          120
# 22  Ashley_Scarlett           48
# 23  Ashley_Scarlett           16
# 24  Ashley_Scarlett           44
# 25  Ashley_Scarlett           15
# 26  Ashley_Scarlett           88
# 27  Ashley_Scarlett           65
# 28  Ashley_Scarlett           25
# 29  Ashley_Scarlett           85
# 30  Ashley_Scarlett          393
# 31  Ashley_Scarlett           12
# 32  Ashley_Scarlett           79
# 33  Ashley_Scarlett          195
# 34  Ashley_Scarlett           85
# 35  Ashley_Scarlett           97
# 36  Ashley_Scarlett           30
# 37  Ashley_Scarlett           22
# 38  Ashley_Scarlett           46
# 39  Ashley_Scarlett           47
# 40  Ashley_Scarlett           10
# 41  Ashley_Scarlett           48
# 42  Ashley_Scarlett          103
# 43  Ashley_Scarlett           60
# 44  Ashley_Scarlett           11
# 45  Ashley_Scarlett          148
#
#                                    text_out_processed
# 0   gentlemen georgia troops well cant get along w...
# 1   dixie dear wife beds dear military district nu...
# 2   whywhyshes like understands feelshed done e th...
# 3   baby house dont believe anything wrong tell wh...
# 4   finally got herenot yetshe wants speak doctor ...
# 5   ive killed ley ive killed news newsdont know f...
# 6   ley hasnt idea im love himhow could know ive a...
# 7   live barbecue till afternoonof course attentiv...
# 8   lets dont hot headed lets dont war misery worl...
# 9   forgive saying know love arent mad youdont sil...
# 10  perhaps old march ride shoot mrs kindly lent w...
# 11  couldnt tonight boy homewhat luckdont giggledo...
# 12  mrs wilkes dont bother husbandi captured first...
# 13  hes skunk ever one whats become alli wonderi w...
# 14  nothing leftnothing left nothing love nothing ...
# 15  ahthats difference even though theyre poor sti...
# 16  loved hell permit come atlanta get tax money i...
# 17  thing wanted tell mewhat change subject baring...
# 18  figger way pa gone nun therell llen left cours...
# 19  tiful voice anyone pa im glad ley id rather pr...
# 20  never said wasnt hes helpless turtle back wilk...
# 21  leyyou must come atlanta need help badly cant ...
# 22  manageri offered half interest heand told alre...
# 23  ley could refuse shes done ungrateful make app...
# 24  oh talked going new york thought nothing atlan...
# 25  thank e darling would crowd well get house oh ...
# 26  england recognized usif jeff commandeered cott...
# 27  youll nothing kind earthly good would ley work...
# 28  amendment letting darkies vote knowit submitte...
# 29  itll make things much harder usoh ley surely t...
# 30  happy dr father father happywell perhaps happy...
# 31  hell hellthat cant leyhe never gets drunk drun...
# 32  downtown time day arent house helping get read...
# 33  hate hear talk like leyyou sound like hes alwa...
# 34  shouldnt let make look backi right said id nev...
# 35  nowi interested explanations know truth better...
# 36  come filthy lies concocted mrs dare course mrs...
# 37  shes always jeas loved best dear shell never c...
# 38  course settled secretbut never kept anything s...
# 39  wants buy outyes course told wouldnt selli wis...
# 40  anything thisiyou know better never go world g...
# 41  lost mindyoull lose money lease kind labor get...
# 42  im afraid people say long im right never felt ...
# 43  train isnt really tell shes better isnt ley sp...
# 44  youre smartso bravealways good meive devil ive...
# 45  love cant wear outyours ley didbut never reall...
#          characters  token_count  \
# 0   Gerald_Scarlett           13
# 1   Gerald_Scarlett           13
# 2   Gerald_Scarlett           12
# 3   Gerald_Scarlett           11
# 4   Gerald_Scarlett           13
# 5   Gerald_Scarlett           11
# 6   Gerald_Scarlett            5
# 7   Gerald_Scarlett           23
# 8   Gerald_Scarlett           55
# 9   Gerald_Scarlett           53
# 10  Gerald_Scarlett          276
# 11  Gerald_Scarlett           13
# 12  Gerald_Scarlett          148
# 13  Gerald_Scarlett           35
# 14  Gerald_Scarlett           13
# 15  Gerald_Scarlett           37
# 16  Gerald_Scarlett           48
# 17  Gerald_Scarlett           39
# 18  Gerald_Scarlett           23
# 19  Gerald_Scarlett           78
# 20  Gerald_Scarlett           26
# 21  Gerald_Scarlett          166
# 22  Gerald_Scarlett           24
# 23  Gerald_Scarlett           73
# 24  Gerald_Scarlett          118
# 25  Gerald_Scarlett           24
# 26  Gerald_Scarlett           50
# 27  Gerald_Scarlett           25
# 28  Gerald_Scarlett          151
#
#                                    text_out_processed
# 0   shes illi brought homecousin yankees already h...
# 1   lamentshe far land young hero sleeps lovers ro...
# 2   cruel war daughterdaughter get well pathe girl...
# 3   hes father poor would die shed go careful care...
# 4   let stay damn yankeesand never expect call any...
# 5   looks ifas knew looked like without shimmy you...
# 6                    brat baptizedyes dead poor thing
# 7   reason bought asked buy herwell use buying goi...
# 8   twelve oaksabout usual cade settled set galler...
# 9   well speak uphe asked kindly sisters said hope...
# 10  im sorry daughter nothing child lots xmother f...
# 11  wish youd quit pushing dont want tara old plan...
# 12  youre young come love land getting away youre ...
# 13  getting another overseer wouldnt cheating eyet...
# 14  mrs takes toss every huntand breaks collar bon...
# 15  drive well wear get horses yet course shes rig...
# 16  hes done well sit till midnightfort sumterof c...
# 17  visiting dancing afterwards twins homewe heard...
# 18  still pussyfoots afraid shadow ill asking inte...
# 19  pa servantsthey know already sure everybody kn...
# 20  ill giving lament robert emmet tis song knowin...
# 21  please go nowi seeing sunday dinnerwurra dayit...
# 22  dear daughter mother girls typhoid ill must ho...
# 23  darlingdont cry shall go home brave little gir...
# 24  said would burning house heads three dying wom...
# 25  tis thing world lasts anyone drop irish blood ...
# 26  wont work fields like darky cant make friends ...
# 27  fault brave like keeping ley home time mill oh...
# 28  ah thought dollar make eyes sparkle sure haven...
#           characters  token_count  \
# 0   Melanie_Scarlett           15
# 1   Melanie_Scarlett           17
# 2   Melanie_Scarlett           13
# 3   Melanie_Scarlett           13
# 4   Melanie_Scarlett           11
# ..               ...          ...
# 90  Melanie_Scarlett           63
# 91  Melanie_Scarlett           53
# 92  Melanie_Scarlett           35
# 93  Melanie_Scarlett           11
# 94  Melanie_Scarlett           51
#
#                                    text_out_processed
# 0   oh good plan knew longed home lovely dress dar...
# 1   money made happy hasnt darling never men like ...
# 2   lie still dear fires gods sake dont try brave ...
# 3   dew blossomoh lawd ladies dont mind stephen im...
# 4   please feet tell go meeting place sooner quit ...
# ..                                                ...
# 90  therehush understandno god dont understand can...
# 91  must hold cant let get awayits promise meoh an...
# 92  leythank god know im worth thank letting knoww...
# 93  good nightpromise meanything darling kind helo...
# 94  dont want word either youi mustnt cry front th...
#
# [95 rows x 3 columns]

# %%
has_rows_with_9_or_less_tokens = (combined_df_Melanie['token_count'] <= 9).any()

print(has_rows_with_9_or_less_tokens)
# Out:
# False

# %%
has_rows_with_9_or_less_tokens = (combined_df_Gerald['token_count'] <= 9).any()

print(has_rows_with_9_or_less_tokens)
# Out:
# True

# %%
has_rows_with_9_or_less_tokens = (combined_df_Melanie['token_count'] <= 9).any()

print(has_rows_with_9_or_less_tokens)
# Out:
# False

# %%
has_rows_with_9_or_less_tokens = (combined_df_Ashley['token_count'] <= 9).any()

print(has_rows_with_9_or_less_tokens)

# %% [markdown]
# ### 5.2 Vectorize text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range = (1, 3))

# %%
convo_df_main['characters'].value_counts()

# %%
def select_equal_groups(group: pd.core.groupby.generic.DataFrameGroupBy, n: int):
    return group.sample(min(n, len(group)), random_state=42)

df_train = convo_df_main.groupby('characters', group_keys=False)\
          .apply(select_equal_groups, 25)

# %%
df_test = convo_df_main[~convo_df_main.index.isin(df_train.index)]

# %%
print(df_train['characters'].value_counts())
print(df_test['characters'].value_counts())

# %%
X_train = vectorizer.fit_transform(df_train['text_out_test'])
X_test = vectorizer.transform(df_test['text_out_test'])
y_train = df_train.characters.reset_index(drop = True)
y_test = df_test.characters.reset_index(drop = True)

# %%
y_train.value_counts()

# %%
y_test.value_counts()

# %% [markdown]
# ##6. Inspect Variables for Correlations

# %%
# # Convert TF-IDF matrix to DataFrame
# tfidf_df = pd.DataFrame(X_tfidf.toarray(), columns=vectorizer.get_feature_names_out())

# # Calculate correlation matrix
# correlation_matrix = tfidf_df.corr()

# # Find highly correlated variables
# highly_correlated = set()
# threshold = 0.98  # You can adjust this threshold as needed

# for i in range(len(correlation_matrix.columns)):
#     for j in range(i):
#         if abs(correlation_matrix.iloc[i, j]) > threshold:
#             colname_i = correlation_matrix.columns[i]
#             colname_j = correlation_matrix.columns[j]
#             highly_correlated.add((colname_i, colname_j))

# print("Highly correlated variables:")
# for pair in highly_correlated:
#     print(pair)

# %% [markdown]
# ##7. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Initialize and fit logistic regression model
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, y_train)

# %%
y_pred = logreg.predict(X_test)

# %%
y_pred

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))

# %%
# !pip install eli5
import eli5
eli5.show_weights(logreg, feature_names = vectorizer.get_feature_names_out())

# %% [markdown]
# ## 8. Network Analysis (to delete?)

# %%
import networkx as nx
G = nx.from_pandas_edgelist(convo_df, 'Character1', 'Character2', edge_attr='character_count', create_using=nx.DiGraph())

# Draw the graph (optional)
nx.draw(G, with_labels=True)

# %%
# Calculate edge centrality (you can use other metrics as well)
edge_centrality = nx.edge_betweenness_centrality(G)

# Sort edges based on centrality or weight (replace 'weight' with your desired metric)
sorted_edges = sorted(edge_centrality.items(), key=lambda x: x[1], reverse=True)

# Create a DataFrame to display top relationships
top_relationships_df = pd.DataFrame(sorted_edges, columns=['Edge', 'Centrality'])

print(top_relationships_df.head(n= 100))

# %% [markdown]
# ## 9. LDA

# %%
from gensim import corpora
from gensim.models import LdaModel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Assume 'df' is your DataFrame containing text data and class labels

# Preprocess the text (e.g., remove stopwords, tokenize)
# Define preprocessing functions as needed

# Vectorize the text
vectorizer = TfidfVectorizer(max_features=1000, stop_words = "english", ngram_range=(2, 4))  # Adjust parameters as needed
X_tfidf = vectorizer.fit_transform(cath_heathcliff_df['text_out'])

# Perform topic modeling (LDA)
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)  # Adjust number of topics
lda_model.fit(X_tfidf)

# %%
num_words = 10

# %%
for topic_id, topic_words in enumerate(lda_model.components_):
    top_word_indices = topic_words.argsort()[:-num_words - 1:-1]
    top_words = [vectorizer.get_feature_names_out()[index] for index in top_word_indices]
    print(f"Topic {topic_id + 1}:")
    print(", ".join(top_words))
    print()
